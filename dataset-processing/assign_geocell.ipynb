# %%
import pandas as pd
import geopandas as gpd

# %%
df_images = pd.read_csv('../resources/mp16_combined.csv')

# %%
gdf = gpd.read_file('../resources/gadm_split_2.gpkg')

# %%
gdf
# Out:
#       GID_2 NAME_2    GID_1   NAME_1 GID_0         NAME_0  image_count  \
# 0                                      ABW          Aruba          464
# 1                                      ATA     Antarctica            0
# 2                                      BVT  Bouvet Island            0
# 3                                      CCK  Cocos Islands            2
# 4                                      CUW        Curaçao          523
# ...     ...    ...      ...      ...   ...            ...          ...
# 11361          _27  SGP.1_1  Central   SGP      Singapore            0
# 11362          _28  SGP.1_1  Central   SGP      Singapore            0
# 11363          _29  SGP.1_1  Central   SGP      Singapore            0
# 11364          _30  SGP.1_1  Central   SGP      Singapore            0
# 11365          _31  SGP.1_1  Central   SGP      Singapore            0
#
#                                                 geometry
# 0      MULTIPOLYGON (((-69.9782 12.46986, -69.97847 1...
# 1      MULTIPOLYGON (((-169.01042 -83.61875, -169.008...
# 2      MULTIPOLYGON (((3.31611 -54.45195, 3.31667 -54...
# 3      MULTIPOLYGON (((96.8419 -12.20306, 96.842 -12....
# 4      MULTIPOLYGON (((-68.64403 11.99958, -68.64403 ...
# ...                                                  ...
# 11361  MULTIPOLYGON (((103.85919 1.28978, 103.86177 1...
# 11362  MULTIPOLYGON (((103.847 1.28502, 103.85189 1.2...
# 11363  MULTIPOLYGON (((103.84938 1.29856, 103.85186 1...
# 11364  MULTIPOLYGON (((103.85564 1.29641, 103.85505 1...
# 11365  MULTIPOLYGON (((103.83387 1.21278, 103.8336 1....
#
# [11366 rows x 8 columns]

# %%
pts = gpd.GeoDataFrame(df_images, geometry=gpd.points_from_xy(df_images['LON'], df_images['LAT']), crs="EPSG:4326")

# %%
joined = gpd.sjoin(pts, gdf[['geometry']], how='left', predicate='within')

# %%
df_images['geocell_index'] = joined['index_right'].values

# %%
df_images
# Out:
#                        IMG_ID        AUTHOR        LAT         LON  S3_Label  \
# 0        92_17_5276763594.jpg  42441750@N03  38.685568 -109.532951       1.0
# 1        0d_ce_6392770405.jpg  68149505@N00  34.933793  103.692741       0.0
# 2        2a_88_5268406683.jpg  84867026@N00  39.983433  -75.243301       0.0
# 3        82_be_2515710583.jpg  75292316@N00  39.306094  -84.379291       1.0
# 4        03_05_9498368699.jpg  61068860@N00   9.186625  123.581597       1.0
# ...                       ...           ...        ...         ...       ...
# 4122114  62_ce_6176671469.jpg  13836188@N04  36.960262  -76.328484       2.0
# 4122115  d3_6f_8552562574.jpg  55715146@N08  36.097019  -80.243766       0.0
# 4122116   2b_22_279705584.jpg  38324365@N00  40.256374 -111.665554       0.0
# 4122117  d9_dd_4097000875.jpg  92292245@N00  32.134131 -101.789231       2.0
# 4122118  d6_89_6763917203.jpg  75201843@N02 -42.332027  146.387243       1.0
#
#          S16_Label  S365_Label   Prob_indoor  Prob_natural  Prob_urban  ...  \
# 0              7.0       289.0  1.739840e-04      0.897409    0.102417  ...
# 1              1.0       122.0  9.968868e-01      0.000578    0.002535  ...
# 2              0.0       128.0  7.201538e-01      0.034871    0.244975  ...
# 3              6.0       145.0  9.050690e-05      0.516982    0.482927  ...
# 4              8.0        36.0  9.902391e-07      0.999983    0.000016  ...
# ...            ...         ...           ...           ...         ...  ...
# 4122114       10.0       207.0  3.058661e-04      0.000160    0.999534  ...
# 4122115        5.0        14.0  9.901024e-01      0.000460    0.009438  ...
# 4122116        2.0       303.0  9.494914e-01      0.022948    0.027560  ...
# 4122117       11.0        86.0  2.011069e-02      0.105259    0.874630  ...
# 4122118        8.0       150.0  4.801794e-02      0.630353    0.321629  ...
#
#                   state           region        country country_code  \
# 0                  Utah              NaN  United States           us
# 1                 Gansu           Linxia          China           cn
# 2          Pennsylvania              NaN  United States           us
# 3                  Ohio              NaN  United States           us
# 4              Siquijor  Central Visayas    Philippines           ph
# ...                 ...              ...            ...          ...
# 4122114        Virginia              NaN  United States           us
# 4122115  North Carolina              NaN  United States           us
# 4122116            Utah              NaN  United States           us
# 4122117           Texas              NaN  United States           us
# 4122118        Tasmania              NaN      Australia           au
#
#         continent                                                URL  \
# 0             NaN  http://farm6.staticflickr.com/5042/5276763594_...
# 1             NaN  http://farm8.staticflickr.com/7172/6392770405_...
# 2             NaN  http://farm6.staticflickr.com/5045/5268406683_...
# 3             NaN  http://farm3.staticflickr.com/2389/2515710583_...
# 4             NaN  http://farm4.staticflickr.com/3800/9498368699_...
# ...           ...                                                ...
# 4122114       NaN  http://farm7.staticflickr.com/6160/6176671469_...
# 4122115       NaN  http://farm9.staticflickr.com/8093/8552562574_...
# 4122116       NaN  http://farm1.staticflickr.com/85/279705584_500...
# 4122117       NaN  http://farm3.staticflickr.com/2715/4097000875_...
# 4122118       NaN  http://farm8.staticflickr.com/7030/6763917203_...
#
#                                                loc_caption  \
# 0        A geo-tagged image taken in Utah, United State...
# 1        A geo-tagged image taken in Lianlu, Gansu, Chi...
# 2        A geo-tagged image taken in Philadelphia, Penn...
# 3         A geo-tagged image taken in Ohio, United States.
# 4        A geo-tagged image taken in Siquijor, Siquijor...
# ...                                                    ...
# 4122114  A geo-tagged image taken in Norfolk, Virginia,...
# 4122115  A geo-tagged image taken in Winston-Salem, Nor...
# 4122116  A geo-tagged image taken in Provo, Utah, Unite...
# 4122117  A geo-tagged image taken in Stanton, Texas, Un...
# 4122118   A geo-tagged image taken in Tasmania, Australia.
#
#                                                cli_caption  \
# 0        A geo-tagged image taken in a Arid, desert, co...
# 1        A geo-tagged image taken in a Cold, dry winter...
# 2        A geo-tagged image taken in a Temperate, no dr...
# 3        A geo-tagged image taken in a Cold, no dry sea...
# 4        A geo-tagged image taken in a Tropical, rainfo...
# ...                                                    ...
# 4122114       A geo-tagged image taken in a other climate.
# 4122115  A geo-tagged image taken in a Temperate, no dr...
# 4122116  A geo-tagged image taken in a Arid, steppe, co...
# 4122117  A geo-tagged image taken in a Arid, steppe, ho...
# 4122118  A geo-tagged image taken in a Temperate, no dr...
#
#                                                tra_caption geocell_index
# 0        A geo-tagged image taken in a right side drivi...        6946.0
# 1        A geo-tagged image taken in a right side drivi...        1538.0
# 2        A geo-tagged image taken in a right side drivi...        8375.0
# 3        A geo-tagged image taken in a right side drivi...        6664.0
# 4        A geo-tagged image taken in a right side drivi...        4833.0
# ...                                                    ...           ...
# 4122114  A geo-tagged image taken in a right side drivi...        7044.0
# 4122115  A geo-tagged image taken in a right side drivi...        6553.0
# 4122116  A geo-tagged image taken in a right side drivi...        6957.0
# 4122117  A geo-tagged image taken in a right side drivi...        6892.0
# 4122118  A geo-tagged imagetaken in a left side driving...         715.0
#
# [4122119 rows x 23 columns]

# %%
df_images.to_csv('../resources/mp16_w_index.csv', index=False)
